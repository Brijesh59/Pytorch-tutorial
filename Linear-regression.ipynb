# %% [markdown]
# First, we can try some toy example: using Pytorch to do linear regression
# Borrow from:
#
# https://github.com/yunjey/pytorch-tutorial/blob/master/tutorials/01-basics/linear_regression
#
# Ke Wang 2019.4.9

# %%
# %matplotlib notebook
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import sigpy.plot as pl

# %% [markdown]
# # Linear Regression: (1-1 Fully connected neural network)

# %%
input_size = 1
output_size = 1
num_epochs = 60
learning_rate = 0.001

# Toy dataset
x_train = np.array([[3.3], [4.4], [5.5], [6.71], [6.93], [4.168], 
                    [9.779], [6.182], [7.59], [2.167], [7.042], 
                    [10.791], [5.313], [7.997], [3.1]], dtype=np.float32)

y_train = np.array([[1.7], [2.76], [2.09], [3.19], [1.694], [1.573], 
                    [3.366], [2.596], [2.53], [1.221], [2.827], 
                    [3.465], [1.65], [2.904], [100]], dtype=np.float32)

# Linear regression model
model = nn.Linear(input_size, output_size) # define a fully connected neural network

# %%
# Let's plot the data:
plt.figure
plt.plot(x_train,y_train,'.')
plt.show()

# %%
# Define the loss and the optimizer
criterion = nn.L1Loss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %%
# Train the model: 
for epoch in range(10000):
    # Convert numpy arrays to torch tensors
    inputs = torch.from_numpy(x_train)
    targets = torch.from_numpy(y_train)

    # Forward pass
    outputs = model(inputs)
    loss = (abs(targets - outputs)).max()
#     loss = 
    
    # Backward and optimize
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if (epoch+1) % 5 == 0:
        print ('Epoch [{}/{}], Loss: {:.4f}'.format(epoch+1, num_epochs, loss.item()))
# Out:
# Epoch [5/60], Loss: 49.5601
# Epoch [10/60], Loss: 49.5436
# Epoch [15/60], Loss: 49.5271
# Epoch [20/60], Loss: 49.5105
# Epoch [25/60], Loss: 49.4940
# Epoch [30/60], Loss: 49.4859
# Epoch [35/60], Loss: 49.5053
# Epoch [40/60], Loss: 49.5246
# Epoch [45/60], Loss: 49.5439
# Epoch [50/60], Loss: 49.5455
# Epoch [55/60], Loss: 49.5290
# Epoch [60/60], Loss: 49.5125
# Epoch [65/60], Loss: 49.4960
# Epoch [70/60], Loss: 49.4795
# Epoch [75/60], Loss: 49.4766
# Epoch [80/60], Loss: 49.4960
# Epoch [85/60], Loss: 49.5153
# Epoch [90/60], Loss: 49.5346
# Epoch [95/60], Loss: 49.5310
# Epoch [100/60], Loss: 49.5145
# Epoch [105/60], Loss: 49.4979
# Epoch [110/60], Loss: 49.4814
# Epoch [115/60], Loss: 49.4649
# Epoch [120/60], Loss: 49.4673
# Epoch [125/60], Loss: 49.4867
# Epoch [130/60], Loss: 49.5060
# Epoch [135/60], Loss: 49.5253
# Epoch [140/60], Loss: 49.5164
# Epoch [145/60], Loss: 49.4999
# Epoch [150/60], Loss: 49.4834
# Epoch [155/60], Loss: 49.4669
# ...

# %%
predicted = model(torch.from_numpy(x_train)).detach().numpy()
plt.plot(x_train, y_train, 'ro', label='Original data')
plt.plot(x_train, predicted, label='Fitted line')
plt.legend()
plt.show()

# Save the model checkpoint
# torch.save(model.state_dict(), 'model.ckpt')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
